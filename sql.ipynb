# %%
from langchain_community.utilities import SQLDatabase

# %%
import os
from dotenv import load_dotenv
load_dotenv()  # take environment variables from .env.
# Out:
# True

# %%
def connectToDB():
    db = SQLDatabase.from_uri("sqlite:///event_company_people.db")
    print(db.dialect)
    print(db.get_usable_table_names())
    print(db.get_context())
    return db

# %%
db=connectToDB()
# Out:
# sqlite
# ['companies', 'events', 'people']
# {'table_info': '\nCREATE TABLE companies (\n\tcompany_logo_url TEXT, \n\tcompany_logo_text TEXT, \n\tcompany_name TEXT, \n\trelation_to_event TEXT, \n\tevent_url TEXT, \n\tcompany_revenue TEXT, \n\tn_employees TEXT, \n\tcompany_phone TEXT, \n\tcompany_founding_year REAL, \n\tcompany_address TEXT, \n\tcompany_industry TEXT, \n\tcompany_overview TEXT, \n\thomepage_url TEXT, \n\tlinkedin_company_url TEXT, \n\thomepage_base_url TEXT, \n\tcompany_logo_url_on_event_page TEXT, \n\tcompany_logo_match_flag TEXT, \n\tcompany_revenue_standardized TEXT, \n\tn_employees_standardized REAL, \n\tcompany_phone_cleaned REAL, \n\thas_logo INTEGER, \n\tdomain TEXT, \n\thas_linkedin INTEGER, \n\tvalid_homepage_base_url INTEGER\n)\n\n/*\n3 rows from companies table:\ncompany_logo_url\tcompany_logo_text\tcompany_name\trelation_to_event\tevent_url\tcompany_revenue\tn_employees\tcompany_phone\tcompany_founding_year\tcompany_address\tcompany_industry\tcompany_overview\thomepage_url\tlinkedin_company_url\thomepage_base_url\tcompany_logo_url_on_event_page\tcompany_logo_match_flag\tcompany_revenue_standardized\tn_employees_standardized\tcompany_phone_cleaned\thas_logo\tdomain\thas_linkedin\tvalid_homepage_base_url\nhttps://d1hbpr09pwz0sk.cloudfront.net/logo_url/100-women-in-finance-6a062f47\tWomen in Finance\t100 Women In Finance\tpartner\thttps://apac.commoditytradingweek.com/\tUnknown\t11-50\tNone\t2001.0\tNone\tfinancial services\t100 Women in Finance strengthens the global finance industry by empowering women to achieve their pr\thttps://100women.org/events/\thttps://www.linkedin.com/company/100-women-in-finance/about\t100women.org\thttps://apac.commoditytradingweek.com/wp-content/uploads/2022/03/100wif_web-1.png\tyes\tNone\t30.5\tNone\t1\t100women.org\t1\t1\nhttps://media.licdn.com/dms/image/C4D0BAQHlTYAmrCwYOw/company-logo_200_200/0/1671349864369/bbgc_serv\tBBGC\tBBGC\tsponsor\thttps://apac.commoditytradingweek.com/\tUnknown\t51-200\tNone\t0.0\tNone\tit services and it consulting\tBusiness Benefits Global Consulting (BBGC) is a multinational consultancy firm with offices in Middl\twww.bbgcservices.com\thttps://it.linkedin.com/company/bbgcservices/about\tbbgcservices.com\thttps://apac.commoditytradingweek.com/wp-content/uploads/2022/03/BBGC_WEB_logo-1.png\tyes\tNone\t125.5\tNone\t1\tNone\t1\t1\nhttps://d1hbpr09pwz0sk.cloudfront.net/logo_url/hr-maritime-c13714f3\tHR MARITIME\tHR Maritime\tpartner\thttps://apac.commoditytradingweek.com/\t$2 million\t2-10\t+41 22 732 57 00\t2008.0\t1-3 Rue De Chantepoulet, Geneva, Geneva 1201, CH\tmaritime transportation\tHR Maritime is a Geneva based company providing services to the International Trading and Shipping i\thttp://www.hr-maritime.com\thttps://ch.linkedin.com/company/hr-maritime/about\thr-maritime.com\thttps://apac.commoditytradingweek.com/wp-content/uploads/2022/03/HR_logo-2.png\tyes\t2000000.0\t6.0\t41227325700.0\t1\thr-maritime.com\t1\t1\n*/\n\n\nCREATE TABLE events (\n\tevent_logo_url TEXT, \n\tevent_name TEXT, \n\tevent_start_date TEXT, \n\tevent_end_date TEXT, \n\tevent_venue TEXT, \n\tevent_country TEXT, \n\tevent_description TEXT, \n\tevent_url TEXT, \n\tevent_duration REAL, \n\thas_logo INTEGER, \n\tevent_year INTEGER, \n\tevent_month INTEGER, \n\tevent_id INTEGER, \n\tevent_industry TEXT, \n\tevent_domain TEXT, \n\tis_virtual INTEGER, \n\tevent_duration_in_days REAL\n)\n\n/*\n3 rows from events table:\nevent_logo_url\tevent_name\tevent_start_date\tevent_end_date\tevent_venue\tevent_country\tevent_description\tevent_url\tevent_duration\thas_logo\tevent_year\tevent_month\tevent_id\tevent_industry\tevent_domain\tis_virtual\tevent_duration_in_days\nhttp://expo.overseaseducation.sg/v.fastcdn.co/u/0e18fcd3/57786581-0-Untitled-.png\tWorld University Expo @ SUNTEC\t2024-07-06\t2024-07-06\tSUNTEC Convention Centre\tSingapore\tJoin our World University Expo this Saturday, 6 July 2024 12-6.30pm at SUNTEC whereby you can meet s\thttp://expo.overseaseducation.sg/\t1.0\t1\t2024\t7\t0\tEducation\texpo.oversease ...

# %%
table_names = db.get_usable_table_names()
table_info = ""
# for table_name in table_names:
columns = db.get_table_info(table_names)
print(columns)
# Out:
# CREATE TABLE companies (
# 	company_logo_url TEXT,
# 	company_logo_text TEXT,
# 	company_name TEXT,
# 	relation_to_event TEXT,
# 	event_url TEXT,
# 	company_revenue TEXT,
# 	n_employees TEXT,
# 	company_phone TEXT,
# 	company_founding_year REAL,
# 	company_address TEXT,
# 	company_industry TEXT,
# 	company_overview TEXT,
# 	homepage_url TEXT,
# 	linkedin_company_url TEXT,
# 	homepage_base_url TEXT,
# 	company_logo_url_on_event_page TEXT,
# 	company_logo_match_flag TEXT,
# 	company_revenue_standardized TEXT,
# 	n_employees_standardized REAL,
# 	company_phone_cleaned REAL,
# 	has_logo INTEGER,
# 	domain TEXT,
# 	has_linkedin INTEGER,
# 	valid_homepage_base_url INTEGER
# )
#
# /*
# 3 rows from companies table:
# company_logo_url	company_logo_text	company_name	relation_to_event	event_url	company_revenue	n_employees	company_phone	company_founding_year	company_address	company_industry	company_overview	homepage_url	linkedin_company_url	homepage_base_url	company_logo_url_on_event_page	company_logo_match_flag	company_revenue_standardized	n_employees_standardized	company_phone_cleaned	has_logo	domain	has_linkedin	valid_homepage_base_url
# https://d1hbpr09pwz0sk.cloudfront.net/logo_url/100-women-in-finance-6a062f47	Women in Finance	100 Women In Finance	partner	https://apac.commoditytradingweek.com/	Unknown	11-50	None	2001.0	None	financial services	100 Women in Finance strengthens the global finance industry by empowering women to achieve their pr	https://100women.org/events/	https://www.linkedin.com/company/100-women-in-finance/about	100women.org	https://apac.commoditytradingweek.com/wp-content/uploads/2022/03/100wif_web-1.png	yes	None	30.5	None	1	100women.org	1	1
# https://media.licdn.com/dms/image/C4D0BAQHlTYAmrCwYOw/company-logo_200_200/0/1671349864369/bbgc_serv	BBGC	BBGC	sponsor	https://apac.commoditytradingweek.com/	Unknown	51-200	None	0.0	None	it services and it consulting	Business Benefits Global Consulting (BBGC) is a multinational consultancy firm with offices in Middl	www.bbgcservices.com	https://it.linkedin.com/company/bbgcservices/about	bbgcservices.com	https://apac.commoditytradingweek.com/wp-content/uploads/2022/03/BBGC_WEB_logo-1.png	yes	None	125.5	None	1	None	1	1
# https://d1hbpr09pwz0sk.cloudfront.net/logo_url/hr-maritime-c13714f3	HR MARITIME	HR Maritime	partner	https://apac.commoditytradingweek.com/	$2 million	2-10	+41 22 732 57 00	2008.0	1-3 Rue De Chantepoulet, Geneva, Geneva 1201, CH	maritime transportation	HR Maritime is a Geneva based company providing services to the International Trading and Shipping i	http://www.hr-maritime.com	https://ch.linkedin.com/company/hr-maritime/about	hr-maritime.com	https://apac.commoditytradingweek.com/wp-content/uploads/2022/03/HR_logo-2.png	yes	2000000.0	6.0	41227325700.0	1	hr-maritime.com	1	1
# */
#
#
# CREATE TABLE events (
# 	event_logo_url TEXT,
# 	event_name TEXT,
# 	event_start_date TEXT,
# 	event_end_date TEXT,
# 	event_venue TEXT,
# 	event_country TEXT,
# 	event_description TEXT,
# 	event_url TEXT,
# 	event_duration REAL,
# 	has_logo INTEGER,
# 	event_year INTEGER,
# 	event_month INTEGER,
# 	event_id INTEGER,
# 	event_industry TEXT,
# 	event_domain TEXT,
# 	is_virtual INTEGER,
# 	event_duration_in_days REAL
# )
#
# /*
# 3 rows from events table:
# event_logo_url	event_name	event_start_date	event_end_date	event_venue	event_country	event_description	event_url	event_duration	has_logo	event_year	event_month	event_id	event_industry	event_domain	is_virtual	event_duration_in_days
# http://expo.overseaseducation.sg/v.fastcdn.co/u/0e18fcd3/57786581-0-Untitled-.png	World University Expo @ SUNTEC	2024-07-06	2024-07-06	SUNTEC Convention Centre	Singapore	Join our World University Expo this Saturday, 6 July 2024 12-6.30pm at SUNTEC whereby you can meet s	http://expo.overseaseducation.sg/	1.0	1	2024	7	0	Education	expo.overseaseducation.sg	0	1.0
# https://ahiceconference.com/southeastasia/wp-content/uploads/sites/2/2024/05/AHICE-SEA-Logo.jpg	AHICE South East Asia	2025-02-25	2025-02-26	Pan Pacific Singapore	Singapore	The Asian Hotel Industry Conference & Exhibition (AHICE) hosted by HM Magazine made its South East A	https://ahiceconference.com/southeastasia/	2.0	1	2025	2	1	Hospitality (Note: This is a distinct category not listed, but the closest match among the provided 	ahiceconference.com	0	2.0
# https://apac.commoditytradingweek.com/wp-content/uploads/2024/02/cropped-ctw-apac-main-2.png	Commodity Trading Week APAC	2025-02-25	2025-02-26	Marina Bay Sands	Singapore	Commodity Trading Week APAC is the premier event in the Asia Pacific region for the commodity indust	https://apac.commoditytradingweek.com/	2.0	1	2025	2	2	Finance	apac.commoditytradingweek.com	0	2.0
# */
#
#
# CREATE TABLE people (
# 	first_name TEXT,
# 	middle_name TEXT,
# 	last_name TEXT,
# 	job_title TEXT,
# 	person_city TEXT,
# 	person_state TEXT,
# 	person_country TEXT,
# 	email_pattern TEXT,
# 	homepage_base_url TEXT,
# 	duration_in_current_job TEXT,
# 	duration_in_current_company TEXT,
# 	full_name TEXT,
# 	generated_email TEXT,
# 	duration_in_current_job_months REAL,
# 	duration_in_current_company_months REAL,
# 	person_id INTEGER,
# 	company_domain TEXT,
# 	job_level TEXT
# )
#
# /*
# 3 rows from people table:
# first_name	middle_name	last_name	job_title	person_city	person_state	person_country	email_pattern	homepage_base_url	duration_in_current_job	duration_in_current_company	full_name	generated_email	duration_in_current_job_months	duration_in_current_company_months	person_id	company_domain	job_level
# Cynthia	None	Battini	Indirect Buyer	Unknown	Unknown	France	None	ariane.group	None	None	Cynthia Battini	no email	None	None	0	ariane.group	Individual Contributor
# Alexander	None	Mcclure	Public Relations	Austin	Tx	Us	None	amazon.com	None	None	Alexander Mcclure	no email	None	None	1	amazon.com	Individual Contributor
# Nadir	None	Shaari	Seo Junior Account Manager	London	Unknown	Gb	[First].[Last]	artefact.com	None	None	Nadir Shaari	nadir.shaari@artefact.com	None	None	2	artefact.com	Middle Management
# */

# %%
# print(os.environ["GROQ_API_KEY"])

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama3-70b-8192")

# %%
prompt = """"

"""

# %%
from langchain.chains import create_sql_query_chain

chain = create_sql_query_chain(llm, db)
response = chain.invoke({"question": "Find me companies that are attending Oil & Gas related events over the next 12 months."})
response
# Out:
# 'SQLQuery: SELECT "company_name", "company_industry" FROM companies WHERE "company_industry" LIKE \'%oil%\' OR "company_industry" LIKE \'%gas%\' AND "event_url" IN (SELECT "event_url" FROM events WHERE "event_start_date" BETWEEN date(\'now\') AND date(\'now\', \'+1 year\') LIMIT 5);'

# %%
db.run('''SELECT "company_name" FROM companies WHERE "company_name" IN (SELECT "company_name" FROM companies c JOIN events e ON c."event_url" = e."event_url" WHERE date(\'now\') <= e."event_start_date" AND e."event_start_date" <= date(\'now\', \'+1 year\'));''')
# Out:
# '[(\'100 Women In Finance\',), (\'BBGC\',), (\'HR Maritime\',), (\'HR Maritime Consultants Ltd\',), (\'Kerry Consulting\',), (\'Marex\',), (\'Marex Inc\',), (\'Marex Solutions\',), (\'Atmospheric G2\',), (\'BIMCO\',), (\'Broadpeak\',), (\'Carbon\',), (\'Cleardox\',), (\'ClearDox LLC\',), (\'CoreTRM\',), (\'deltaconX AG\',), (\'Fenics USTreasuries\',), (\'Fenics Market Data\',), (\'Institute of Chartered Shipbrokers\',), (\'CommodityThursdays\',), (\'ITFA Americas (AMRC)\',), (\'Komgo\',), (\'Nanyang Business School\',), (\'Polestar\',), (\'POLESTAR GLOBAL LIMITED\',), (\'Propeller Club-Geneva\',), (\'SGX RegCo\',), (\'Singapore Mining Club\',), (\'Trade Data Monitor LLC\',), (\'The Broker Club\',), (\'Bloomberg\',), (\'TradeFlow Capital Management\',), (\'Value Creed\',), (\'WIMAR SG\',), (\'WISTA Singapore\',), (\'Synspective Inc.\',), (\'Airbus Defence and Space\',), (\'ICEYE\',), (\'ST Engineering North America\',), (\'Singapore Land Authority (SLA)\',), (\'IAI - Israel Aerospace Industries\',), (\'Lighthaus Inc\',), (\'MetaSensing\',), (\'National Supercomputing Centre (NSCC) Singapore\',), (\'Satrec Initiative Co., Ltd.\',), (\'University of Surrey\',), (\'City of Surrey\',), (\'Surrey County Council\',), (\'Kymeta Corporation\',), (\'Mitsubishi Electric\',), (\'Mitsubishi Electric\',), (\'Rocket Factory Augsburg-RFA\',), (\'ARIANESPACE\',), (\'ArianeGroup\',), (\'Australian Geographic\',), (\'Australian Space Agency\',), (\'BlackSky\',), (\'CONTEC CO., LTD.\',), (\'Contec Holdings\',), (\'CONTEC MEDICAL SYSTEMS CO.,LTD\',), (\'Contec, Inc.\',), (\'University of Toronto Institute for Aerospace Studies Space Flight Lab\',), (\'University of Toronto Institute for Aerospace Studies\',), (\'InSpace Proximity\',), (\'Kacific Broadband Satellites Group\',), (\'Air-Way Global Manufacturing Company\',), (\'GSOA\',), (\'IDDK Co., Ltd.\',), (\'Satellite Evolution Group\',), (\'SkyFi\',), (\'Sol de Janeiro\',), (\'Sol Blume\',), (\'Space Ambition\',), (\'Japan Aerospace Exploration Agency\',), (\'NaraSpace\',), (\'Teledyne DALSA\',), (\'Teledyne LeCroy\',), (\'Teledyne Advanced Electronic Solutions\',), (\'Teledyne Technologies Incorporated\',), (\'Teledyne Marine\',), (\'VAST\',), (\'AgniKul Cosmos\',), (\'HawkEye 360\',), (\'The Italian Chamber of Commerce in Singapore\',), (\'JSAT INTERNATIONAL, INC.\',), (\'SKY Perfect JSAT (スカパーJSAT)\',), (\'MEDs Technologies\',), (\'GoTyme Bank\',), (\'Endava\',), (\'Doctor Care Anywhere\',), (\'Doctor Anywhere\',), (\'Revival Rugs\',), (\'Tonik\',), (\'Tonik\',), (\'ShopBack\',), (\'Seamless.AI\',), (\'Seamless\',), (\'Franchise India Holdings Limited\',), (\'FranchiseBAZAR\',), (\'ANEXT Bank\',), (\'Barnett Harley-Davidson\',), (\'Harley-Davidson Motor Company\',), (\'Parcel Perform\',), (\'Texas Rural Water Association (TRWA)\',), (\'SolarWinds\',), (\'ACN Newswire\',), (\'KnowBe4\',), (\'Acronis\',), (\'HUMAN\',), (\'Events Industry Council\',), (\'Industry Events\',), (\'Bizzabo\',), (\'LastPass\',), (\'Cloudflare\',), (\'Versa Networks\',), (\'BlackBerry\',), (\'Netskope\',), (\'Splunk\',), (\'Ivanti\',), (\'Delinea\',), (\'Sophos\',), (\'Aryaka\',), (\'SentinelOne\',), (\'Fireye\',), (\'FireEye, Inc.\',), (\'Halodata Indonesia\',), (\'Cato Networks-Asia\',), (\'Kissflow\',), (\'Darktrace\',), (\'ISACA\',), (\'Exito Travel\',), (\'Okta\',), (\'Zscaler\',), (\'Centre for Cyber Security\',), (\'Centre For Cybersecurity Institute\',), (\'The Apache Software Foundation\',), (\'Tech For Good Institute\',), (\'Cyber Defense Magazine\',), (\'Medium\',), (\'Block Tides\',), (\'Global Business and Finance Magazine\',), (\'Monetary Authority of Singapore (MAS)\',), (\'Singapore Tourism Board\',), (\'Visit Singapore Business Events\',), (\'Synology\',), (\'Exabeam\',), (\'IT Knowledge Zone\',), (\'SailPoint\',), (\'SUSE\',), (\'openSUSE Project\',), (\'Hackuity\',), (\'Pro-invest Group\',), (\'Marriott International Hotels, Inc.\',), (\'TravMedia\',), (\'Bandcamp\',), (\'Niantic, Inc.\',), (\'Photo ...

# %%
from langchain_community.agent_toolkits.sql.toolkit import SQLDatabaseToolkit

# %%
toolkit = SQLDatabaseToolkit(db=db, llm=llm)

tools = toolkit.get_tools()

tools
# Out:
# [QuerySQLDataBaseTool(description="Input to this tool is a detailed and correct SQL query, output is a result from the database. If the query is not correct, an error message will be returned. If an error is returned, rewrite the query, check the query, and try again. If you encounter an issue with Unknown column 'xxxx' in 'field list', use sql_db_schema to query the correct table fields.", db=<langchain_community.utilities.sql_database.SQLDatabase object at 0x000001FC83C49790>),
#  InfoSQLDatabaseTool(description='Input to this tool is a comma-separated list of tables, output is the schema and sample rows for those tables. Be sure that the tables actually exist by calling sql_db_list_tables first! Example Input: table1, table2, table3', db=<langchain_community.utilities.sql_database.SQLDatabase object at 0x000001FC83C49790>),
#  ListSQLDatabaseTool(db=<langchain_community.utilities.sql_database.SQLDatabase object at 0x000001FC83C49790>),
#  QuerySQLCheckerTool(description='Use this tool to double check if your query is correct before executing it. Always use this tool before executing a query with sql_db_query!', db=<langchain_community.utilities.sql_database.SQLDatabase object at 0x000001FC83C49790>, llm=ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000001FC83CAF2D0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001FC83CBC650>, model_name='llama3-70b-8192', groq_api_key=SecretStr('**********')), llm_chain=LLMChain(prompt=PromptTemplate(input_variables=['dialect', 'query'], template='\n{query}\nDouble check the {dialect} query above for common mistakes, including:\n- Using NOT IN with NULL values\n- Using UNION when UNION ALL should have been used\n- Using BETWEEN for exclusive ranges\n- Data type mismatch in predicates\n- Properly quoting identifiers\n- Using the correct number of arguments for functions\n- Casting to the correct data type\n- Using the proper columns for joins\n\nIf there are any of the above mistakes, rewrite the query. If there are no mistakes, just reproduce the original query.\n\nOutput the final SQL query only.\n\nSQL Query: '), llm=ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000001FC83CAF2D0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001FC83CBC650>, model_name='llama3-70b-8192', groq_api_key=SecretStr('**********'))))]

# %%
from langchain_core.messages import SystemMessage

SQL_PREFIX = """You are an agent designed to interact with a SQL database.
Given an input question, create a syntactically correct SQLite query to run, then look at the results of the query and return the answer.
Unless the user specifies a specific number of examples they wish to obtain, always limit your query to at most 5 results.
You can order the results by a relevant column to return the most interesting examples in the database.
Never query for all the columns from a specific table, only ask for the relevant columns given the question.
You have access to tools for interacting with the database.
Only use the below tools. Only use the information returned by the below tools to construct your final answer.
You MUST double check your query before executing it. If you get an error while executing a query, rewrite the query and try again.

DO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the database.

To start you should ALWAYS look at the tables in the database to see what you can query.
Do NOT skip this step.
Then you should query the schema of the most relevant tables."""

system_message = SystemMessage(content=SQL_PREFIX)

# %%
from langchain_core.messages import HumanMessage
from langgraph.prebuilt import create_react_agent

agent_executor = create_react_agent(llm, tools, messages_modifier=system_message)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19680\1800557427.py:4: LangGraphDeprecationWarning: Parameter 'messages_modifier' in function 'create_react_agent' is deprecated as of version 0.1.9 and will be removed in version 0.3.0. Use 'state_modifier' parameter instead.
#   agent_executor = create_react_agent(llm, tools, messages_modifier=system_message)

# %%
example_query = "Find me companies that are attending Oil & Gas related events?"

events = agent_executor.stream(
    {"messages": [("user", example_query)]},
    stream_mode="values",
)
for event in events:
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Find me companies that are attending Oil & Gas related events?
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_list_tables (call_4p2a)
#  Call ID: call_4p2a
#   Args:
#     tool_input:
# ================================= Tool Message =================================
# Name: sql_db_list_tables
#
# companies, events, people
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_schema (call_nqa5)
#  Call ID: call_nqa5
#   Args:
#     table_names: companies, events
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE companies (
# 	company_logo_url TEXT,
# 	company_logo_text TEXT,
# 	company_name TEXT,
# 	relation_to_event TEXT,
# 	event_url TEXT,
# 	company_revenue TEXT,
# 	n_employees TEXT,
# 	company_phone TEXT,
# 	company_founding_year REAL,
# 	company_address TEXT,
# 	company_industry TEXT,
# 	company_overview TEXT,
# 	homepage_url TEXT,
# 	linkedin_company_url TEXT,
# 	homepage_base_url TEXT,
# 	company_logo_url_on_event_page TEXT,
# 	company_logo_match_flag TEXT,
# 	company_revenue_standardized TEXT,
# 	n_employees_standardized REAL,
# 	company_phone_cleaned REAL,
# 	has_logo INTEGER,
# 	domain TEXT,
# 	has_linkedin INTEGER,
# 	valid_homepage_base_url INTEGER
# )
#
# /*
# 3 rows from companies table:
# company_logo_url	company_logo_text	company_name	relation_to_event	event_url	company_revenue	n_employees	company_phone	company_founding_year	company_address	company_industry	company_overview	homepage_url	linkedin_company_url	homepage_base_url	company_logo_url_on_event_page	company_logo_match_flag	company_revenue_standardized	n_employees_standardized	company_phone_cleaned	has_logo	domain	has_linkedin	valid_homepage_base_url
# https://d1hbpr09pwz0sk.cloudfront.net/logo_url/100-women-in-finance-6a062f47	Women in Finance	100 Women In Finance	partner	https://apac.commoditytradingweek.com/	Unknown	11-50	None	2001.0	None	financial services	100 Women in Finance strengthens the global finance industry by empowering women to achieve their pr	https://100women.org/events/	https://www.linkedin.com/company/100-women-in-finance/about	100women.org	https://apac.commoditytradingweek.com/wp-content/uploads/2022/03/100wif_web-1.png	yes	None	30.5	None	1	100women.org	1	1
# https://media.licdn.com/dms/image/C4D0BAQHlTYAmrCwYOw/company-logo_200_200/0/1671349864369/bbgc_serv	BBGC	BBGC	sponsor	https://apac.commoditytradingweek.com/	Unknown	51-200	None	0.0	None	it services and it consulting	Business Benefits Global Consulting (BBGC) is a multinational consultancy firm with offices in Middl	www.bbgcservices.com	https://it.linkedin.com/company/bbgcservices/about	bbgcservices.com	https://apac.commoditytradingweek.com/wp-content/uploads/2022/03/BBGC_WEB_logo-1.png	yes	None	125.5	None	1	None	1	1
# https://d1hbpr09pwz0sk.cloudfront.net/logo_url/hr-maritime-c13714f3	HR MARITIME	HR Maritime	partner	https://apac.commoditytradingweek.com/	$2 million	2-10	+41 22 732 57 00	2008.0	1-3 Rue De Chantepoulet, Geneva, Geneva 1201, CH	maritime transportation	HR Maritime is a Geneva based company providing services to the International Trading and Shipping i	http://www.hr-maritime.com	https://ch.linkedin.com/company/hr-maritime/about	hr-maritime.com	https://apac.commoditytradingweek.com/wp-content/uploads/2022/03/HR_logo-2.png	yes	2000000.0	6.0	41227325700.0	1	hr-maritime.com	1	1
# */
#
#
# CREATE TABLE events (
# 	event_logo_url TEXT,
# 	event_name TEXT,
# 	event_start_date TEXT,
# 	event_end_date TEXT,
# 	event_venue TEXT,
# 	event_country TEXT,
# 	event_description TEXT,
# 	event_url TEXT,
# 	event_duration REAL,
# 	has_logo INTEGER,
# 	event_year INTEGER,
# 	event_month INTEGER,
# 	event_id INTEGER,
# 	event_industry TEXT,
# 	event_domain TEXT,
# 	is_virtual INTEGER,
# 	event_duration_in_days REAL
# )
#
# /*
# 3 rows from events table:
# event_logo_url	event_name	event_start_date	event_end_date	event_venue	event_country	event_description	event_url	event_duration	has_logo	event_year	event_month	event_id	event_industry	event_domain	is_virtual	event_duration_in_days
# http://expo.overseaseducation.sg/v.fastcdn.co/u/0e18fcd3/57786581-0-Untitled-.png	World University Expo @ SUNTEC	2024-07-06	2024-07-06	SUNTEC Convention Centre	Singapore	Join our World University Expo this Saturday, 6 July 2024 12-6.30pm at SUNTEC whereby you can meet s	http://expo.overseaseducation.sg/	1.0	1	2024	7	0	Education	expo.overseaseducation.sg	0	1.0
# https://ahiceconference.com/southeastasia/wp-content/uploads/sites/2/2024/05/AHICE-SEA-Logo.jpg	AHICE South East Asia	2025-02-25	2025-02-26	Pan Pacific Singapore	Singapore	The Asian Hotel Industry Conference & Exhibition (AHICE) hosted by HM Magazine made its South East A	https://ahiceconference.com/southeastasia/	2.0	1	2025	2	1	Hospitality (Note: This is a distinct category not listed, but the closest match among the provided 	ahiceconference.com	0	2.0
# https://apac.commoditytradingweek.com/wp-content/uploads/2024/02/cropped-ctw-apac-main-2.png	Commodity Trading Week APAC	2025-02-25	2025-02-26	Marina Bay Sands	Singapore	Commodity Trading Week APAC is the premier event in the Asia Pacific region for the commodity indust	https://apac.commoditytradingweek.com/	2.0	1	2025	2	2	Finance	apac.commoditytradingweek.com	0	2.0
# */
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query_checker (call_8by8)
#  Call ID: call_8by8
#   Args:
#     query: SELECT company_name, event_url FROM companies WHERE relation_to_event LIKE '%partner%' OR relation_to_event LIKE '%sponsor%'
# ================================= Tool Message =================================
# Name: sql_db_query_checker
#
# SELECT company_name, event_url FROM companies WHERE relation_to_event LIKE '%partner%' OR relation_to_event LIKE '%sponsor%'
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query (call_b30n)
#  Call ID: call_b30n
#   Args:
#     query: SELECT company_name, event_url FROM companies WHERE relation_to_event LIKE '%partner%' OR relation_to_event LIKE '%sponsor%'
# ================================= Tool Message =================================
# Name: sql_db_query
#
# [('100 Women In Finance', 'https://apac.commoditytradingweek.com/'), ('BBGC', 'https://apac.commoditytradingweek.com/'), ('HR Maritime', 'https://apac.commoditytradingweek.com/'), ('HR Maritime Consultants Ltd', 'https://apac.commoditytradingweek.com/'), ('Kerry Consulting', 'https://apac.commoditytradingweek.com/'), ('Marex', 'https://apac.commoditytradingweek.com/'), ('Marex Inc', 'https://apac.commoditytradingweek.com/'), ('Marex Solutions', 'https://apac.commoditytradingweek.com/'), ('BIMCO', 'https://apac.commoditytradingweek.com/'), ('Broadpeak', 'https://apac.commoditytradingweek.com/'), ('Cleardox', 'https://apac.commoditytradingweek.com/'), ('ClearDox LLC', 'https://apac.commoditytradingweek.com/'), ('deltaconX AG', 'https://apac.commoditytradingweek.com/'), ('Institute of Chartered Shipbrokers', 'https://apac.commoditytradingweek.com/'), ('CommodityThursdays', 'https://apac.commoditytradingweek.com/'), ('ITFA Americas (AMRC)', 'https://apac.commoditytradingweek.com/'), ('Polestar', 'https://apac.commoditytradingweek.com/'), ('POLESTAR GLOBAL LIMITED', 'https://apac.commoditytradingweek.com/'), ('Propeller Club-Geneva', 'https://apac.commoditytradingweek.com/'), ('SGX RegCo', 'https://apac.commoditytradingweek.com/'), ('Singapore Mining Club', 'https://apac.commoditytradingweek.com/'), ('Trade Data Monitor LLC', 'https://apac.commoditytradingweek.com/'), ('The Broker Club', 'https://apac.commoditytradingweek.com/'), ('Bloomberg', 'https://apac.commoditytradingweek.com/'), ('Value Creed', 'https://apac.commoditytradingweek.com/'), ('WIMAR SG', 'https://apac.commoditytradingweek.com/'), ('WISTA Singapore', 'https://apac.commoditytradingweek.com/'), ('Synspective Inc.', 'https://www.space.org.sg/gstc/'), ('Airbus Defence and Space', 'https://www.space.org.sg/gstc/'), ('ICEYE', 'https://www.space.org.sg/gstc/'), ('ST Engineering North America', 'https://www.space.org.sg/gstc/'), ('Singapore Land Authority (SLA)', 'https://www.space.org.sg/gstc/'), ('IAI - Israel Aerospace Industries', 'https://www.space.org.sg/gstc/'), ('Lighthaus Inc', 'https://www.space.org.sg/gstc/'), ('MetaSensing', 'https://www.space.org.sg/gstc/'), ('National Supercomputing Centre (NSCC) Singapore', 'https://www.space.org.sg/gstc/'), ('Satrec Initiative Co., Ltd.', 'https://www.space.org.sg/gstc/'), ('University of Surrey', 'https://www.space.org.sg/gstc/'), ('City of Surrey', 'https://www.space.org.sg/gstc/'), ('Surrey County Council', 'https://www.space.org.sg/gstc/'), ('Kymeta Corporation', 'https://www.space.org.sg/gstc/'), ('Mitsubishi Electric', 'https://www.space.org.sg/gstc/'), ('Mitsubishi Electric', 'https://www.space.org.sg/gstc/'), ('Rocket Factory Augsburg-RFA', 'https://www.space.org.sg/gstc/'), ('ARIANESPACE', 'https://www.space.org.sg/gstc/'), ('ArianeGroup', 'https://www.space.org.sg/gstc/'), ('Australian Geographic', 'https://www.space.org.sg/gstc/'), ('Australian Space Agency', 'https://www.space.org.sg/gstc/'), ('BlackSky', 'https://www.space.org.sg/gstc/'), ('CONTEC CO., LTD.', 'https://www.space.org.sg/gstc/'), ('Contec Holdings', 'https://www.space.org.sg/gstc/'), ('CONTEC MEDICAL SYSTEMS CO.,LTD', 'https://www.space.org.sg/gstc/'), ('Contec, Inc.', 'https://www.space.org.sg/gstc/'), ('University of Toronto Institute for Aerospace Studies Space Flight Lab', 'https://www.space.org.sg/gstc/'), ('University of Toronto Institute for Aerospace Studies', 'https://www.space.org.sg/gstc/'), ('InSpace Proximity', 'https://www.space.org.sg/gstc/'), ('Kacific Broadband Satellites Group', 'https://www.space.org.sg/gstc/'), ('Air-Way Global Manufacturing Company', 'https://www.space.org.sg/gstc/'), ('GSOA', 'https://www.space.org.sg/gstc/'), ('IDDK Co., Ltd.', 'https://www.space.org.sg/gstc/'), ('Satellite Evolution Group', 'https://www.space.org.sg/gstc/'), ('SkyFi', 'https://www.space.org.sg/gstc/'), ('Sol de Janeiro', 'https://www.space.org.sg/gstc/'), ('Sol Blume', 'https://www.space.org.sg/gstc/'), ('Space Ambition', 'https://www.spac ...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[20], line 7
#       1 example_query = "Find me companies that are attending Oil & Gas related events?"
#       3 events = agent_executor.stream(
#       4     {"messages": [("user", example_query)]},
#       5     stream_mode="values",
#       6 )
# ----> 7 for event in events:
#       8     event["messages"][-1].pretty_print()
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langgraph\pregel\__init__.py:984, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug)
#     981         del fut, task
#     983 # panic on failure or timeout
# --> 984 _panic_or_proceed(done, inflight, loop.step)
#     985 # don't keep futures around in memory longer than needed
#     986 del done, inflight, futures
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langgraph\pregel\__init__.py:1385, in _panic_or_proceed(done, inflight, step, timeout_exc_cls)
#    1383             inflight.pop().cancel()
#    1384         # raise the exception
# -> 1385         raise exc
#    1387 if inflight:
#    1388     # if we got here means we timed out
#    1389     while inflight:
#    1390         # cancel all pending tasks
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langgraph\pregel\executor.py:60, in BackgroundExecutor.done(self, task)
#      58 def done(self, task: concurrent.futures.Future) -> None:
#      59     try:
# ---> 60         task.result()
#      61     except GraphInterrupt:
#      62         # This exception is an interruption signal, not an error
#      63         # so we don't want to re-raise it on exit
#      64         self.tasks.pop(task)
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langgraph\pregel\retry.py:25, in run_with_retry(task, retry_policy)
#      23 task.writes.clear()
#      24 # run the task
# ---> 25 task.proc.invoke(task.input, task.config)
#      26 # if successful, end
#      27 break
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\runnables\base.py:2876, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2874 context.run(_set_config_context, config)
#    2875 if i == 0:
# -> 2876     input = context.run(step.invoke, input, config, **kwargs)
#    2877 else:
#    2878     input = context.run(step.invoke, input, config)
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\runnables\base.py:4475, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4461 """Invoke this Runnable synchronously.
#    4462
#    4463 Args:
#    (...)
#    4472     TypeError: If the Runnable is a coroutine function.
#    4473 """
#    4474 if hasattr(self, "func"):
# -> 4475     return self._call_with_config(
#    4476         self._invoke,
#    4477         input,
#    4478         self._config(config, self.func),
#    4479         **kwargs,
#    4480     )
#    4481 else:
#    4482     raise TypeError(
#    4483         "Cannot invoke a coroutine function synchronously."
#    4484         "Use `ainvoke` instead."
#    4485     )
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\runnables\base.py:1785, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1781     context = copy_context()
#    1782     context.run(_set_config_context, child_config)
#    1783     output = cast(
#    1784         Output,
# -> 1785         context.run(
#    1786             call_func_with_variable_args,  # type: ignore[arg-type]
#    1787             func,  # type: ignore[arg-type]
#    1788             input,  # type: ignore[arg-type]
#    1789             config,
#    1790             run_manager,
#    1791             **kwargs,
#    1792         ),
#    1793     )
#    1794 except BaseException as e:
#    1795     run_manager.on_chain_error(e)
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\runnables\config.py:427, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     425 if run_manager is not None and accepts_run_manager(func):
#     426     kwargs["run_manager"] = run_manager
# --> 427 return func(input, **kwargs)
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\runnables\base.py:4331, in RunnableLambda._invoke(self, input, run_manager, config, **kwargs)
#    4329                 output = chunk
#    4330 else:
# -> 4331     output = call_func_with_variable_args(
#    4332         self.func, input, config, run_manager, **kwargs
#    4333     )
#    4334 # If the output is a Runnable, invoke it
#    4335 if isinstance(output, Runnable):
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\runnables\config.py:427, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     425 if run_manager is not None and accepts_run_manager(func):
#     426     kwargs["run_manager"] = run_manager
# --> 427 return func(input, **kwargs)
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langgraph\prebuilt\chat_agent_executor.py:445, in create_react_agent.<locals>.call_model(state, config)
#     441 def call_model(
#     442     state: AgentState,
#     443     config: RunnableConfig,
#     444 ):
# --> 445     response = model_runnable.invoke(state, config)
#     446     if state["is_last_step"] and response.tool_calls:
#     447         return {
#     448             "messages": [
#     449                 AIMessage(
#    (...)
#     453             ]
#     454         }
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\runnables\base.py:2878, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2876             input = context.run(step.invoke, input, config, **kwargs)
#    2877         else:
# -> 2878             input = context.run(step.invoke, input, config)
#    2879 # finish the root run
#    2880 except BaseException as e:
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\runnables\base.py:5094, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5088 def invoke(
#    5089     self,
#    5090     input: Input,
#    5091     config: Optional[RunnableConfig] = None,
#    5092     **kwargs: Optional[Any],
#    5093 ) -> Output:
# -> 5094     return self.bound.invoke(
#    5095         input,
#    5096         self._merge_configs(config),
#    5097         **{**self.kwargs, **kwargs},
#    5098     )
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\language_models\chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
#     290             run_name=config.get("run_name"),
#     291             run_id=config.pop("run_id", None),
#     292             **kwargs,
#     293         ).generations[0][0],
#     294     ).message
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\language_models\chat_models.py:756, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     748 def generate_prompt(
#     749     self,
#     750     prompts: List[PromptValue],
#    (...)
#     753     **kwargs: Any,
#     754 ) -> LLMResult:
#     755     prompt_messages = [p.to_messages() for p in prompts]
# --> 756     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\language_models\chat_models.py:613, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     611         if run_managers:
#     612             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 613         raise e
#     614 flattened_outputs = [
#     615     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     616     for res in results
#     617 ]
#     618 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\language_models\chat_models.py:603, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     600 for i, m in enumerate(messages):
#     601     try:
#     602         results.append(
# --> 603             self._generate_with_cache(
#     604                 m,
#     605                 stop=stop,
#     606                 run_manager=run_managers[i] if run_managers else None,
#     607                 **kwargs,
#     608             )
#     609         )
#     610     except BaseException as e:
#     611         if run_managers:
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_core\language_models\chat_models.py:825, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     823 else:
#     824     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 825         result = self._generate(
#     826             messages, stop=stop, run_manager=run_manager, **kwargs
#     827         )
#     828     else:
#     829         result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\langchain_groq\chat_models.py:472, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     467 message_dicts, params = self._create_message_dicts(messages, stop)
#     468 params = {
#     469     **params,
#     470     **kwargs,
#     471 }
# --> 472 response = self.client.create(messages=message_dicts, **params)
#     473 return self._create_chat_result(response)
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\groq\resources\chat\completions.py:289, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     148 def create(
#     149     self,
#     150     *,
#    (...)
#     177     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     178 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     179     """
#     180     Creates a model response for the given chat conversation.
#     181
#    (...)
#     287       timeout: Override the client-level default timeout for this request, in seconds
#     288     """
# --> 289     return self._post(
#     290         "/openai/v1/chat/completions",
#     291         body=maybe_transform(
#     292             {
#     293                 "messages": messages,
#     294                 "model": model,
#     295                 "frequency_penalty": frequency_penalty,
#     296                 "function_call": function_call,
#     297                 "functions": functions,
#     298                 "logit_bias": logit_bias,
#     299                 "logprobs": logprobs,
#     300                 "max_tokens": max_tokens,
#     301                 "n": n,
#     302                 "parallel_tool_calls": parallel_tool_calls,
#     303                 "presence_penalty": presence_penalty,
#     304                 "response_format": response_format,
#     305                 "seed": seed,
#     306                 "stop": stop,
#     307                 "stream": stream,
#     308                 "temperature": temperature,
#     309                 "tool_choice": tool_choice,
#     310                 "tools": tools,
#     311                 "top_logprobs": top_logprobs,
#     312                 "top_p": top_p,
#     313                 "user": user,
#     314             },
#     315             completion_create_params.CompletionCreateParams,
#     316         ),
#     317         options=make_request_options(
#     318             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     319         ),
#     320         cast_to=ChatCompletion,
#     321         stream=stream or False,
#     322         stream_cls=Stream[ChatCompletionChunk],
#     323     )
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\groq\_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)
#    1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\groq\_base_client.py:920, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     911 def request(
#     912     self,
#     913     cast_to: Type[ResponseT],
#    (...)
#     918     stream_cls: type[_StreamT] | None = None,
#     919 ) -> ResponseT | _StreamT:
# --> 920     return self._request(
#     921         cast_to=cast_to,
#     922         options=options,
#     923         stream=stream,
#     924         stream_cls=stream_cls,
#     925         remaining_retries=remaining_retries,
#     926     )
#
# File c:\Users\DELL\anaconda3\envs\dbc\Lib\site-packages\groq\_base_client.py:1018, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1015         err.response.read()
#    1017     log.debug("Re-raising status error")
# -> 1018     raise self._make_status_error_from_response(err.response) from None
#    1020 return self._process_response(
#    1021     cast_to=cast_to,
#    1022     options=options,
#    (...)
#    1025     stream_cls=stream_cls,
#    1026 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01j3y6s0z6emqsrydr2cme87jt` on tokens per minute (TPM): Limit 6000, Used 7407, Requested 13347. Please try again in 2m27.54s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}

# %%
from langchain import hub
prompt_template = hub.pull("langchain-ai/sql-agent-system-prompt")

# %%
prompt_template
# Out:
# ChatPromptTemplate(input_variables=['dialect', 'top_k'], metadata={'lc_hub_owner': 'langchain-ai', 'lc_hub_repo': 'sql-agent-system-prompt', 'lc_hub_commit_hash': '31156d5fe3945188ee172151b086712d22b8c70f8f1c0505f5457594424ed352'}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['dialect', 'top_k'], template='You are an agent designed to interact with a SQL database.\nGiven an input question, create a syntactically correct {dialect} query to run, then look at the results of the query and return the answer.\nUnless the user specifies a specific number of examples they wish to obtain, always limit your query to at most {top_k} results.\nYou can order the results by a relevant column to return the most interesting examples in the database.\nNever query for all the columns from a specific table, only ask for the relevant columns given the question.\nYou have access to tools for interacting with the database.\nOnly use the below tools. Only use the information returned by the below tools to construct your final answer.\nYou MUST double check your query before executing it. If you get an error while executing a query, rewrite the query and try again.\n\nDO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the database.\n\nTo start you should ALWAYS look at the tables in the database to see what you can query.\nDo NOT skip this step.\nThen you should query the schema of the most relevant tables.'))])
